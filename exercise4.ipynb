# %% [markdown]
# # General tasks and directions
#
# - Add your name, today's date, and the assignment title to the designated cell.
# - Write your answers in the cells that contain `Add your answer here.` line.
# - Write your code in the cells that contain `# Add your implementation here.` line.
# - Use autograder tests that are provided for your convenience.
# - Don't change or delete any provided code (including [cell magic](https://ipython.readthedocs.io/en/stable/interactive/magics.html) such as `%%capture output`).

# %% [markdown]
# ## Add your name, today's date, and the assignment title
#
# author: Muhammad Mughees Warraich
#
# date: Apr 3
#
# assignment: exercise 4

# %% [markdown]
# # Data visualization
#
# *Using `matplotlib` to visuialize historical Fortune500 data*
#
# This assignment is individual and you agree to submit your own work.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

from pandas import Series, DataFrame

np.set_printoptions(precision=2, suppress=True, linewidth=120)

pd.options.display.max_rows = 20

plt.rc("figure", figsize=(8, 4))

# %% [markdown]
# ## Data preparation
#
# Read the data from the provided *fortune500.csv* into a `DataFrame`.
#
# Drop "(in millions)" from the names of the columns so that dot-notation can be used to access them.
#
# Set data type of the *Company* column to a string and data type of the "Profit (in millions)" to a floating-point number.

# %%
df = pd.read_csv("fortune500.csv")

df.rename({"Revenue (in millions)": "Revenue", "Profit (in millions)": "Profit"},
          axis="columns",
          inplace=True)

df.Company = df.Company.astype(pd.StringDtype())
df.Profit = pd.to_numeric(df.Profit, errors="coerce")

# %% [markdown]
# ## Task 1
#
# Plot the historical revenue of three companies, *General Dynamics*, *General Electric*, and *General Motors*.
#
# The figure must have 4 subplots, 3 companies individually and 1 plot with all three companies.
#
# `x`-axis on each plot must be the year and `y`-axis must be the revenue of the company that year. It's easier to achieve if `Year` is an index of the series with a company revenue.
#
# Your figure should look similar (though not necessarily identical) to the following:
#
# ![Task 1](task1.png)

# %%
df
# Out:
#        Year  Rank                Company  Revenue  Profit
# 0      1955     1         General Motors   9823.5   806.0
# 1      1955     2            Exxon Mobil   5661.4   584.8
# 2      1955     3             U.S. Steel   3250.4   195.4
# 3      1955     4       General Electric   2959.1   212.6
# 4      1955     5                 Esmark   2510.8    19.1
# ...     ...   ...                    ...      ...     ...
# 25495  2005   496        Wm. Wrigley Jr.   3648.6   493.0
# 25496  2005   497         Peabody Energy   3631.6   175.4
# 25497  2005   498  Wendy's International   3630.4    57.8
# 25498  2005   499     Kindred Healthcare   3616.6    70.6
# 25499  2005   500   Cincinnati Financial   3614.0   584.0
#
# [25500 rows x 5 columns]

# %%
print(df.columns)
# Out:
# Index(['Year', 'Rank', 'Company', 'Revenue', 'Profit'], dtype='object')

# %%
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(2, 3, 1)
ax2 = fig.add_subplot(2, 3, 2)
ax3 = fig.add_subplot(2, 3, 3)
ax4 = fig.add_subplot(2, 1, 2)

# %%
ax1.plot(df.loc[df['Company'] == 'General Dynamics', 'Year'], df.loc[df['Company'] == 'General Dynamics', 'Revenue'], color='blue')
ax1.set_title('General Dynamics')
ax1.set_xlabel('Year')
ax1.set_ylabel('Revenue ($B)')

ax2.plot(df.loc[df['Company'] == 'General Electric', 'Year'], df.loc[df['Company'] == 'General Electric', 'Revenue'], color='green')
ax2.set_title('General Electric')
ax2.set_xlabel('Year')
ax2.set_ylabel('Revenue ($B)')

ax3.plot(df.loc[df['Company'] == 'General Motors', 'Year'], df.loc[df['Company'] == 'General Motors', 'Revenue'], color='red')
ax3.set_title('General Motors')
ax3.set_xlabel('Year')
ax3.set_ylabel('Revenue ($B)')

ax4.plot(df.loc[df['Company'] == 'General Dynamics', 'Year'], df.loc[df['Company'] == 'General Dynamics', 'Revenue'], color='blue')
ax4.set_title('General Dynamics')
ax4.set_xlabel('Year')
ax4.set_ylabel('Revenue ($B)')

ax4.plot(df.loc[df['Company'] == 'General Electric', 'Year'], df.loc[df['Company'] == 'General Electric', 'Revenue'], color='green')
ax4.set_title('General Electric')
ax4.set_xlabel('Year')
ax4.set_ylabel('Revenue ($B)')

ax4.plot(df.loc[df['Company'] == 'General Motors', 'Year'], df.loc[df['Company'] == 'General Motors', 'Revenue'], color='red')
ax4.set_title('General Motors')
ax4.set_xlabel('Year')
ax4.set_ylabel('Revenue ($B)')
# Out:
# Text(4.444444444444452, 0.5, 'Revenue ($B)')

# %% [markdown]
# ax_combined = fig.add_subplot(1, 1, 1)
# ax_combined.plot(df.loc[df['Company'] == 'General Dynamics', 'Year'], df.loc[df['Company'] == 'General Dynamics', 'Revenue'], color='blue', label='General Dynamics')
# ax_combined.plot(df.loc[df['Company'] == 'General Electric', 'Year'], df.loc[df['Company'] == 'General Electric', 'Revenue'], color='green', label='General Electric')
# ax_combined.plot(df.loc[df['Company'] == 'General Motors', 'Year'], df.loc[df['Company'] == 'General Motors', 'Revenue'], color='red', label='General Motors')
# ax_combined.set_title('Combined Revenue')
# ax_combined.set_xlabel('Year')
# ax_combined.set_ylabel('Revenue ($B)')
# ax_combined.legend()

# %%
fig

# %% [markdown]
# ## Task 2
#
# Plot the total profits of *Hershey Foods* by decade as a bar chart.
#
# A decade is ten years that share the first 3 digits, so the figure must include 6 decades: 50s, 60s, 70s, 80s, 90s, and 00s.
#
# Your figure should look similar (though not necessarily identical) to the following:
#
# ![Task 2](task2.png)

# %%
# Add your implementation here.
df
# Out:
#        Year  Rank                Company  Revenue  Profit
# 0      1955     1         General Motors   9823.5   806.0
# 1      1955     2            Exxon Mobil   5661.4   584.8
# 2      1955     3             U.S. Steel   3250.4   195.4
# 3      1955     4       General Electric   2959.1   212.6
# 4      1955     5                 Esmark   2510.8    19.1
# ...     ...   ...                    ...      ...     ...
# 25495  2005   496        Wm. Wrigley Jr.   3648.6   493.0
# 25496  2005   497         Peabody Energy   3631.6   175.4
# 25497  2005   498  Wendy's International   3630.4    57.8
# 25498  2005   499     Kindred Healthcare   3616.6    70.6
# 25499  2005   500   Cincinnati Financial   3614.0   584.0
#
# [25500 rows x 5 columns]

# %%
Hersheys_data = df[df.Company == "Hershey Foods"]

# %%
Hersheys_data
# Out:
#        Year  Rank        Company  Revenue  Profit
# 196    1955   197  Hershey Foods    159.4     7.1
# 725    1956   226  Hershey Foods    151.6    10.6
# 1260   1957   261  Hershey Foods    148.7    12.9
# 1762   1958   263  Hershey Foods    157.8    14.9
# 2244   1959   245  Hershey Foods    164.0    12.7
# ...     ...   ...            ...      ...     ...
# 23397  2001   398  Hershey Foods   4221.0   334.5
# 23861  2002   362  Hershey Foods   4557.2   207.2
# 24389  2003   390  Hershey Foods   4120.3   403.6
# 24914  2004   415  Hershey Foods   4172.6   457.6
# 25435  2005   436  Hershey Foods   4429.2   590.9
#
# [51 rows x 5 columns]

# %%
profits_by_decade = Hersheys_data.groupby(Hersheys_data["Year"] // 10 * 10).sum(numeric_only=True)["Profit"]

profits_by_decade.plot(kind="bar")
plt.xlabel("Decade")
plt.ylabel("Profits (in millions)")
plt.title("Hershey Foods")
# Out:
# Text(0.5, 1.0, 'Hershey Foods')

# %% [markdown]
# ## Task 3
#
# Plot the revenue and rank of *Microsoft* as a scatterplot.
#
# Revenue must be the `x`-axis, rank must be the inverted `y`-axis.
#
# Your figure should look similar (though not necessarily identical) to the following:
#
# ![Task 3](task3.png)

# %%
# Add your implementation here.
df
# Out:
#        Year  Rank                Company  Revenue  Profit
# 0      1955     1         General Motors   9823.5   806.0
# 1      1955     2            Exxon Mobil   5661.4   584.8
# 2      1955     3             U.S. Steel   3250.4   195.4
# 3      1955     4       General Electric   2959.1   212.6
# 4      1955     5                 Esmark   2510.8    19.1
# ...     ...   ...                    ...      ...     ...
# 25495  2005   496        Wm. Wrigley Jr.   3648.6   493.0
# 25496  2005   497         Peabody Energy   3631.6   175.4
# 25497  2005   498  Wendy's International   3630.4    57.8
# 25498  2005   499     Kindred Healthcare   3616.6    70.6
# 25499  2005   500   Cincinnati Financial   3614.0   584.0
#
# [25500 rows x 5 columns]

# %%
microsoft_data = df[df["Company"] == "Microsoft"]

plt.scatter(microsoft_data["Revenue"], microsoft_data["Rank"].sort_values(ascending=False))
plt.xlabel("Revenue (in billions)")
plt.ylabel("Rank")
plt.title("Microsoft's Revenue and Rank")
plt.gca().invert_yaxis()  # Invert the y-axis
plt.show()

# %% [markdown]
# ## Task 4
#
# Plot IBM's (*Intl. Business Machines*) annual rank between 1965 and 2005, annotating the following dates:
#
# - 1970: "Relational DB"
# - 1981: "IBM PC"
# - 1997: "Deep Blue"
#
# The `y`-axis should be inverted and limited to `[0..15]` to make changes in ranking more visible.
#
# Your figure should look similar (though not necessarily identical) to the following:
#
# ![Task 4](task4.png)

# %%
# Add your implementation here.
IBM_data = df[df["Company"] == "Intl. Business Machines"]

# %%
IBM_data
# Out:
#        Year  Rank                  Company  Revenue  Profit
# 60     1955    61  Intl. Business Machines    461.4    46.5
# 558    1956    59  Intl. Business Machines    563.5    55.9
# 1047   1957    48  Intl. Business Machines    734.3    68.8
# 1536   1958    37  Intl. Business Machines   1000.4    89.3
# 2027   1959    28  Intl. Business Machines   1171.8   126.2
# ...     ...   ...                      ...      ...     ...
# 23007  2001     8  Intl. Business Machines  88396.0  8093.0
# 23508  2002     9  Intl. Business Machines  85866.0  7723.0
# 24007  2003     8  Intl. Business Machines  83132.0  3579.0
# 24508  2004     9  Intl. Business Machines  89131.0  7583.0
# 25009  2005    10  Intl. Business Machines  96293.0  8430.0
#
# [51 rows x 5 columns]

# %%
IBM_data = IBM_data[IBM_data['Year'] > 1965]
ibm_rank_df = IBM_data[['Year', 'Rank']]

# Create the plot
plt.figure(figsize=(10,5))
plt.plot(ibm_rank_df['Year'], ibm_rank_df['Rank'])

# Add the annotations
plt.annotate('Relational DB', xy=(1970, 6), xytext=(1967.5, 10), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate('IBM PC', xy=(1981, 9), xytext=(1979.75, 14), arrowprops=dict(facecolor='black', arrowstyle='->'))
plt.annotate('Deep Blue', xy=(1997, 7), xytext=(1995, 10), arrowprops=dict(facecolor='black', arrowstyle='->'))

# Set the y-axis limits and invert it
plt.ylim(15, 0)

# Add labels and a title
plt.xlabel('Year')
plt.ylabel('Rank')
plt.title('IBM')

# Display the plot
plt.show()

# %% [markdown]
# ## Task 5
#
# Plot Apple's (*Apple Computers*) annual profit and mark Steve Jobs's absence (1985-1997) as a red zone (rectangle).
#
# Your figure should look similar (though not necessarily identical) to the following:
#
# ![Task 5](task5.png)

# %%
# Add your implementation here.
apple_data = df[df["Company"] == "Apple Computer"]

# %%
apple_data
# Out:
#        Year  Rank         Company  Revenue  Profit
# 14410  1983   411  Apple Computer    583.1    61.3
# 14798  1984   299  Apple Computer    982.8    76.7
# 15233  1985   234  Apple Computer   1515.9    64.1
# 15690  1986   191  Apple Computer   1918.3    61.2
# 16189  1987   190  Apple Computer   1901.9   154.0
# ...     ...   ...             ...      ...     ...
# 23235  2001   236  Apple Computer   7983.0   786.0
# 23824  2002   325  Apple Computer   5363.0   -25.0
# 24299  2003   300  Apple Computer   5742.0    65.0
# 24800  2004   301  Apple Computer   6207.0    69.0
# 25262  2005   263  Apple Computer   8279.0   276.0
#
# [23 rows x 5 columns]

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(apple_data['Year'], apple_data['Profit'])


y_min, y_max = ax.get_ylim()
rect = plt.Rectangle((1985, y_min), 12, y_max-y_min, color="red", alpha=0.3)

ax.add_patch(rect)

# %% [markdown]
# ## Submission Checklist
#
# - [ ] Your name, today's date, and the assignment title in the designated cell.
# - [ ] Your answers in the designated cells (if required).
# - [ ] Your code runs and produces the expected output.
# - [ ] The validity of your code is verified by autograders (if provided).
# - [ ] Restart the kernel and run all cells (in the menubar, select *Kernel*, then *Restart Kernel and Run All Cells*).
# - [ ] Save the notebook.
# - [ ] Submit the assignment.
